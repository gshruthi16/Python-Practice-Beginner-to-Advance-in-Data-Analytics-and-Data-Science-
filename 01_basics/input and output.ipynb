# %% [markdown]
# ## INPUT AND OUTPUT

# %% [markdown]
# ### Q1. Print this exact sentence:
#
# ### The Titanic dataset has 891 rows and 15 columns.

# %%
print("The Titanic dataset has 891 rows and 15 columns.")
# Out:
# The Titanic dataset has 891 rows and 15 columns.

# %% [markdown]
# ### Q2. Store the number of passengers in a variable called total_passengers and print it like this:
#
# ### Total passengers on Titanic: 891

# %%
total_passengers = 891
print("Total passengers on Titanic: ", total_passengers)
# Out:
# Total passengers on Titanic:  891

# %% [markdown]
# ### Q3. Ask the user to enter a passenger class (1, 2, or 3) using input() and store it in a variable called pclass. Print back:
#
# ### You selected class: 3

# %%
pclass = int(input("Enter the class (1, 2 or 3): "))
print("You have selected the class : ", pclass)
# Out:
# Enter the class (1, 2 or 3):  1
# You have selected the class :  1

# %% [markdown]
# ### Q4. Ask the user to enter their name. Print:
#
# ### Welcome [name]! Let's explore the Titanic dataset together.

# %%
name = input("Enter your Name : ")
print(f"Welcome {name}! Let's explore the Titanic dataset together.")
# Out:
# Enter your Name :  Shruthi
# Welcome Shruthi ! Let's explore the Titanic dataset together.

# %% [markdown]
# ### Q5. Store the survival rate as 38.3855 in a variable. Print it formatted to exactly 2 decimal places:
#
# ### Titanic survival rate: 38.38%

# %%
survival_rate = 38.3855
print(f"Titanic survival rate: {survival_rate:.2f}%")
# Out:
# Titanic survival rate: 38.39%

# %% [markdown]
# ### Q6. Store fare as 71.2833. Print it rounded to 2 decimal places:
#
# ### Average fare paid: 71.28

# %%
fare = 71.2833
print(f"The fare is: {fare:.2f}")
# Out:
# The fare is: 71.28

# %% [markdown]
# ### Q7. Ask user to input an age. Print whether they would have been a child (under 18) or adult on the Titanic. Just the print logic — no pandas yet.

# %%
age = int(input("Enter the age : "))

if age < 18 :
    print ("You would have been a child on the Titanic")
else :
    print ("You would have been an adult on the Titanic")
# Out:
# Enter the age :  18
# You would have been an adult on the Titanic

# %% [markdown]
# ### Q8. Print these 3 lines using a single print statement:
#
# Dataset: Titanic
#
# Rows: 891
#
# Columns: 15

# %%
Dataset, Rows, Columns = 'Titanic', 891, 15

print('Dataset = ',Dataset,'\n','Number of Rows = ',Rows,'\n','Number of Columns = ',Columns)
# Out:
# Dataset =  Titanic
#  Number of Rows =  891
#  Number of Columns =  15

# %% [markdown]
# ### Q9. Store survived = 342 and died = 549. Print:
#
# Survived: 342 | Did not survive: 549

# %%
survived = 342
died = 549

print("Survived : ", survived, "| Did not survive: ", died)
# Out:
# Survived :  342 | Did not survive:  549

# %% [markdown]
# ### Q10. Ask the user to enter any column name. Print:
# You want to explore the [column name] column. Good choice!

# %%
col_name = input("Enter the column name : ")

print(f"You want to explore the {col_name} column. Good choice!")
# Out:
# Enter the column name :  hahaha
# You want to explore the hahaha column. Good choice!
